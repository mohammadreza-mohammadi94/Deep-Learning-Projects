# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammadreza-mohammadi94/Deep-Learning-Projects/blob/main/UrbanSound8K-Audio-Classification-EfficientNet/UrbanSound_ConvNet_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
chrisfilo_urbansound8k_path = kagglehub.dataset_download('chrisfilo/urbansound8k')

print('Data source import complete.')
# Out:
# Using Colab cache for faster access to the 'urbansound8k' dataset.
# Data source import complete.

# %% [markdown]
# # Imports

# %%
import os
import cv2
import numpy as np
import pandas as pd
import librosa
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, label_binarize
from sklearn.metrics import (confusion_matrix,
                             classification_report,
                             roc_curve, auc)

import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import (Dense, GlobalAveragePooling2D,
                                     Conv2D, MaxPooling2D, Flatten,
                                     Dropout, BatchNormalization)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %% [markdown]
# # Configuration

# %%
# Paths based on the Kaggle input structure
BASE_PATH = '/kaggle/input/urbansound8k'
METADATA_PATH = os.path.join(BASE_PATH, 'UrbanSound8K.csv')

# Audio settings
SAMPLE_RATE = 22050
DURATION = 4  # Duration in seconds
SAMPLES_PER_TRACK = SAMPLE_RATE * DURATION

# Image settings for EfficientNet
IMG_HEIGHT = 128
IMG_WIDTH = 128
CHANNELS = 3  # RGB
BATCH_SIZE = 32
EPOCHS = 15
NUM_CLASSES = 10
TEST_FOLD = 10

# Set to None to load the full dataset (takes longer)
# Set to an integer (e.g., 2000) for debugging/fast testing
DATA_LIMIT = None

# %% [markdown]
# # Helper Functions

# %%
def get_spectrogram(file_path, augment=False):
    try:
        y, sr = librosa.load(file_path, sr=22050)

        # Handle audio length
        max_len = 22050 * 4
        if len(y) > max_len:
            y = y[:max_len]
        else:
            y = np.pad(y, (0, max_len - len(y)), mode='constant')

        if augment:
            noise_amp = 0.005 * np.random.uniform() * np.amax(y)
            y = y + noise_amp * np.random.normal(size=y.shape[0])

        mel_spec = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=256, fmax=8000)
        mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)

        img = (mel_spec_db - mel_spec_db.min()) / (mel_spec_db.max() - mel_spec_db.min())

        # Resize to fixed dimensions
        img = cv2.resize(img, (128, 128)) # Note: tuple (128, 128)

        # Convert to 3 channels
        img = np.stack((img,) * 3, axis=-1)

        # Ensure data type
        return img.astype(np.float32)

    except Exception as e:
        print(f"Error: {e}")
        return None

# %% [markdown]
# # Data Pipeline

# %%
def load_data_by_folds(metadata_path, base_path, test_fold_num):
    # Read the metadata CSV file into a pandas DataFrame
    df = pd.read_csv(metadata_path)

    # Initialize lists to store training and validation data and labels
    train_data, train_labels = [], []
    val_data, val_labels = [], []

    print(f"⏳ Loading Data (Test Fold: {test_fold_num})...")

    # Iterate through each row in the DataFrame to process audio files
    for _, row in tqdm(df.iterrows(), total=df.shape[0]):
        fold = row['fold']
        # Construct the full file path for the audio file
        file_path = os.path.join(base_path, f"fold{fold}", row['slice_file_name'])
        label = row['classID'] # Use classID directly (0-9) as the label

        # Check if the current fold is the designated test fold
        if fold == test_fold_num:
            # For validation data, do not apply augmentation
            spec = get_spectrogram(file_path, augment=False)
            if spec is not None:
                val_data.append(spec)
                val_labels.append(label)

        else:
            # For training data, apply augmentation
            spec = get_spectrogram(file_path, augment=True)
            if spec is not None:
                train_data.append(spec)
                train_labels.append(label)

    # Convert lists to NumPy arrays before returning
    return (np.array(train_data), np.array(train_labels)), \
           (np.array(val_data), np.array(val_labels)), df

# Load the dataset, splitting into training and validation sets based on the TEST_FOLD
(X_train, y_train_idx), (X_val, y_val_idx), metadata_df = load_data_by_folds(METADATA_PATH, BASE_PATH, TEST_FOLD)

# Initialize and fit LabelEncoder here
label_encoder = LabelEncoder()
label_encoder.fit(metadata_df['class'].unique())

# Convert integer labels to one-hot encoded categorical format for Keras
y_train = to_categorical(y_train_idx, 10)
y_val = to_categorical(y_val_idx, 10)

# Print the shapes of the prepared training and validation datasets
print(f"Train: {X_train.shape}, Val: {X_val.shape}")
# Out:
# ⏳ Loading Data (Test Fold: 10)...
# 100%|██████████| 8732/8732 [06:19<00:00, 23.02it/s]
# Train: (7895, 128, 128, 3), Val: (837, 128, 128, 3)

# %% [markdown]
# # Model Definition

# %%
def build_robust_cnn(input_shape, num_classes):
    model = Sequential([

        # --- Block 1 ---
        # L2 Regularizer limits the weights to prevent overfitting
        Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(0.001), input_shape=input_shape),
        BatchNormalization(), # Normalizes data for faster training
        MaxPooling2D((2, 2)),
        Dropout(0.3), # 30% dropout rate

        # --- Block 2 ---
        Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(0.001)),
        BatchNormalization(),
        MaxPooling2D((2, 2)),
        Dropout(0.3),

        # --- Block 3 ---
        Conv2D(128, (3, 3), activation='relu', kernel_regularizer=l2(0.001)),
        BatchNormalization(),
        MaxPooling2D((2, 2)),
        Dropout(0.4), # Higher dropout rate in deeper layers

        # --- Classifier Head ---
        Flatten(),

        # Dense layer with more neurons but heavy dropout
        Dense(256, activation='relu', kernel_regularizer=l2(0.001)),
        BatchNormalization(),
        Dropout(0.5), # Drops 50% of neurons at each step (strong prevention of overfitting)

        # Output layer
        Dense(num_classes, activation='softmax')
    ])

    # Compile settings with Label Smoothing
    # label_smoothing=0.1 means instead of saying the probability is 100%, it says 90%.
    # This prevents the loss from exploding suddenly.
    optimizer = Adam(learning_rate=0.001)
    loss = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1)

    model.compile(optimizer=optimizer,
                  loss=loss,
                  metrics=['accuracy'])

    return model

# Build the model
model_robust = build_robust_cnn((IMG_HEIGHT, IMG_WIDTH, CHANNELS), NUM_CLASSES)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ## Training

# %%
# Define Callbacks
callbacks = [
    # Save the best model (only when validation loss decreases)
    ModelCheckpoint(
        'best_simple_cnn.keras',
        monitor='val_loss',
        save_best_only=True,
        mode='min',
        verbose=1
    ),

    # Smart Stopping (if no improvement for 7 epochs)
    EarlyStopping(
        monitor='val_loss',
        patience=7,
        restore_best_weights=True,
        verbose=1
    ),

    # Reduce Learning Rate (if stuck, decrease speed)
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,       # Reduce learning rate by half
        patience=3,       # If no improvement for 3 epochs
        min_lr=1e-6,
        verbose=1
    )
]

print("Starting Training Simple CNN...")
# Start Training
history = model_robust.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_val, y_val),
    callbacks=callbacks
)
# Out:
# Starting Training Simple CNN...
# Epoch 1/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4136 - loss: 2.9203
# Epoch 1: val_loss improved from inf to 4.39455, saving model to best_simple_cnn.keras
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 24s 58ms/step - accuracy: 0.4139 - loss: 2.9191 - val_accuracy: 0.1350 - val_loss: 4.3945 - learning_rate: 0.0010
# Epoch 2/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6778 - loss: 2.2297
# Epoch 2: val_loss improved from 4.39455 to 3.59126, saving model to best_simple_cnn.keras
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.6780 - loss: 2.2293 - val_accuracy: 0.2676 - val_loss: 3.5913 - learning_rate: 0.0010
# Epoch 3/50
# 246/247 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7811 - loss: 1.9479
# Epoch 3: val_loss did not improve from 3.59126
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.7812 - loss: 1.9479 - val_accuracy: 0.5663 - val_loss: 4.6765 - learning_rate: 0.0010
# Epoch 4/50
# 245/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8364 - loss: 1.8510
# Epoch 4: val_loss improved from 3.59126 to 2.53017, saving model to best_simple_cnn.keras
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 0.8364 - loss: 1.8511 - val_accuracy: 0.5783 - val_loss: 2.5302 - learning_rate: 0.0010
# Epoch 5/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8609 - loss: 1.8114
# Epoch 5: val_loss did not improve from 2.53017
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.8609 - loss: 1.8114 - val_accuracy: 0.3202 - val_loss: 3.3483 - learning_rate: 0.0010
# Epoch 6/50
# 245/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8260 - loss: 2.0624
# Epoch 6: val_loss did not improve from 2.53017
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.8260 - loss: 2.0640 - val_accuracy: 0.5460 - val_loss: 2.9870 - learning_rate: 0.0010
# Epoch 7/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8814 - loss: 2.0373
# Epoch 7: val_loss improved from 2.53017 to 2.49815, saving model to best_simple_cnn.keras
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - accuracy: 0.8814 - loss: 2.0370 - val_accuracy: 0.6296 - val_loss: 2.4982 - learning_rate: 0.0010
# Epoch 8/50
# 246/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9154 - loss: 1.7805
# Epoch 8: val_loss improved from 2.49815 to 2.29112, saving model to best_simple_cnn.keras
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.9154 - loss: 1.7805 - val_accuracy: 0.6428 - val_loss: 2.2911 - learning_rate: 0.0010
# Epoch 9/50
# 246/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9112 - loss: 1.7552
# Epoch 9: val_loss did not improve from 2.29112
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.9112 - loss: 1.7553 - val_accuracy: 0.5568 - val_loss: 2.8964 - learning_rate: 0.0010
# Epoch 10/50
# 246/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9170 - loss: 1.7450
# Epoch 10: val_loss did not improve from 2.29112
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.9170 - loss: 1.7450 - val_accuracy: 0.5579 - val_loss: 2.6366 - learning_rate: 0.0010
# Epoch 11/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9147 - loss: 1.8039
# Epoch 11: val_loss did not improve from 2.29112
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.9146 - loss: 1.8041 - val_accuracy: 0.4671 - val_loss: 2.8843 - learning_rate: 0.0010
# Epoch 12/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9456 - loss: 1.7473
# Epoch 12: val_loss did not improve from 2.29112
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.9456 - loss: 1.7469 - val_accuracy: 0.5400 - val_loss: 2.4454 - learning_rate: 5.0000e-04
# Epoch 13/50
# 246/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9659 - loss: 1.4532
# Epoch 13: val_loss improved from 2.29112 to 2.05821, saving model to best_simple_cnn.keras
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.9659 - loss: 1.4530 - val_accuracy: 0.6380 - val_loss: 2.0582 - learning_rate: 5.0000e-04
# Epoch 14/50
# 246/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9685 - loss: 1.3295
# Epoch 14: val_loss improved from 2.05821 to 1.75721, saving model to best_simple_cnn.keras
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.9685 - loss: 1.3294 - val_accuracy: 0.7407 - val_loss: 1.7572 - learning_rate: 5.0000e-04
# Epoch 15/50
# 246/247 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9719 - loss: 1.2718
# Epoch 15: val_loss did not improve from 1.75721
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9718 - loss: 1.2719 - val_accuracy: 0.6177 - val_loss: 2.0768 - learning_rate: 5.0000e-04
# Epoch 16/50
# 246/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9735 - loss: 1.2472
# Epoch 16: val_loss did not improve from 1.75721
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.9735 - loss: 1.2472 - val_accuracy: 0.5436 - val_loss: 2.3128 - learning_rate: 5.0000e-04
# Epoch 17/50
# 246/247 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9709 - loss: 1.2368
# Epoch 17: val_loss did not improve from 1.75721
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.9709 - loss: 1.2368 - val_accuracy: 0.6714 - val_loss: 1.8544 - learning_rate: 5.0000e-04
# Epoch 18/50
# 246/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9803 - loss: 1.1875
# Epoch 18: val_loss improved from 1.75721 to 1.67053, saving model to best_simple_cnn.keras
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - accuracy: 0.9803 - loss: 1.1873 - val_accuracy: 0.7013 - val_loss: 1.6705 - learning_rate: 2.5000e-04
# Epoch 19/50
# 246/247 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9861 - loss: 1.0852
# Epoch 19: val_loss improved from 1.67053 to 1.52299, saving model to best_simple_cnn.keras
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.9861 - loss: 1.0851 - val_accuracy: 0.7431 - val_loss: 1.5230 - learning_rate: 2.5000e-04
# Epoch 20/50
# 246/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9893 - loss: 1.0287
# Epoch 20: val_loss improved from 1.52299 to 1.48371, saving model to best_simple_cnn.keras
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - accuracy: 0.9893 - loss: 1.0286 - val_accuracy: 0.7419 - val_loss: 1.4837 - learning_rate: 2.5000e-04
# Epoch 21/50
# 246/247 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9879 - loss: 0.9925
# Epoch 21: val_loss did not improve from 1.48371
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.9879 - loss: 0.9924 - val_accuracy: 0.7145 - val_loss: 1.5347 - learning_rate: 2.5000e-04
# Epoch 22/50
# 245/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9908 - loss: 0.9656
# Epoch 22: val_loss improved from 1.48371 to 1.43149, saving model to best_simple_cnn.keras
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - accuracy: 0.9907 - loss: 0.9656 - val_accuracy: 0.7479 - val_loss: 1.4315 - learning_rate: 2.5000e-04
# Epoch 23/50
# 245/247 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9897 - loss: 0.9453
# Epoch 23: val_loss improved from 1.43149 to 1.40618, saving model to best_simple_cnn.keras
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.9896 - loss: 0.9453 - val_accuracy: 0.7515 - val_loss: 1.4062 - learning_rate: 2.5000e-04
# Epoch 24/50
# 246/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9899 - loss: 0.9354
# Epoch 24: val_loss did not improve from 1.40618
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.9899 - loss: 0.9354 - val_accuracy: 0.7407 - val_loss: 1.4119 - learning_rate: 2.5000e-04
# Epoch 25/50
# 246/247 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9886 - loss: 0.9327
# Epoch 25: val_loss did not improve from 1.40618
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.9886 - loss: 0.9327 - val_accuracy: 0.7372 - val_loss: 1.4932 - learning_rate: 2.5000e-04
# Epoch 26/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9892 - loss: 0.9297
# Epoch 26: val_loss did not improve from 1.40618
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.9892 - loss: 0.9297 - val_accuracy: 0.7133 - val_loss: 1.4905 - learning_rate: 2.5000e-04
# Epoch 27/50
# 246/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9899 - loss: 0.9139
# Epoch 27: val_loss did not improve from 1.40618
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.9899 - loss: 0.9139 - val_accuracy: 0.7395 - val_loss: 1.4102 - learning_rate: 1.2500e-04
# Epoch 28/50
# 246/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9941 - loss: 0.8748
# Epoch 28: val_loss improved from 1.40618 to 1.35695, saving model to best_simple_cnn.keras
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.9941 - loss: 0.8747 - val_accuracy: 0.7419 - val_loss: 1.3570 - learning_rate: 1.2500e-04
# Epoch 29/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9952 - loss: 0.8432
# Epoch 29: val_loss improved from 1.35695 to 1.35522, saving model to best_simple_cnn.keras
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.9952 - loss: 0.8432 - val_accuracy: 0.7360 - val_loss: 1.3552 - learning_rate: 1.2500e-04
# Epoch 30/50
# 246/247 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9957 - loss: 0.8228
# Epoch 30: val_loss improved from 1.35522 to 1.28424, saving model to best_simple_cnn.keras
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.9957 - loss: 0.8228 - val_accuracy: 0.7611 - val_loss: 1.2842 - learning_rate: 1.2500e-04
# Epoch 31/50
# 245/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9961 - loss: 0.8029
# Epoch 31: val_loss improved from 1.28424 to 1.28277, saving model to best_simple_cnn.keras
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - accuracy: 0.9961 - loss: 0.8029 - val_accuracy: 0.7658 - val_loss: 1.2828 - learning_rate: 1.2500e-04
# Epoch 32/50
# 246/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9952 - loss: 0.7925
# Epoch 32: val_loss improved from 1.28277 to 1.25312, saving model to best_simple_cnn.keras
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.9952 - loss: 0.7924 - val_accuracy: 0.7766 - val_loss: 1.2531 - learning_rate: 1.2500e-04
# Epoch 33/50
# 245/247 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9971 - loss: 0.7824
# Epoch 33: val_loss did not improve from 1.25312
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9971 - loss: 0.7824 - val_accuracy: 0.7527 - val_loss: 1.2778 - learning_rate: 1.2500e-04
# Epoch 34/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9960 - loss: 0.7792
# Epoch 34: val_loss did not improve from 1.25312
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.9960 - loss: 0.7791 - val_accuracy: 0.7587 - val_loss: 1.2554 - learning_rate: 1.2500e-04
# Epoch 35/50
# 245/247 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9970 - loss: 0.7673
# Epoch 35: val_loss did not improve from 1.25312
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9970 - loss: 0.7673 - val_accuracy: 0.7407 - val_loss: 1.2786 - learning_rate: 1.2500e-04
# Epoch 36/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9967 - loss: 0.7597
# Epoch 36: val_loss improved from 1.25312 to 1.22819, saving model to best_simple_cnn.keras
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.9967 - loss: 0.7596 - val_accuracy: 0.7634 - val_loss: 1.2282 - learning_rate: 6.2500e-05
# Epoch 37/50
# 245/247 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9980 - loss: 0.7470
# Epoch 37: val_loss improved from 1.22819 to 1.21791, saving model to best_simple_cnn.keras
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.9980 - loss: 0.7470 - val_accuracy: 0.7706 - val_loss: 1.2179 - learning_rate: 6.2500e-05
# Epoch 38/50
# 245/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9982 - loss: 0.7319
# Epoch 38: val_loss improved from 1.21791 to 1.19247, saving model to best_simple_cnn.keras
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - accuracy: 0.9982 - loss: 0.7320 - val_accuracy: 0.7754 - val_loss: 1.1925 - learning_rate: 6.2500e-05
# Epoch 39/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9972 - loss: 0.7259
# Epoch 39: val_loss did not improve from 1.19247
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9972 - loss: 0.7258 - val_accuracy: 0.7336 - val_loss: 1.2685 - learning_rate: 6.2500e-05
# Epoch 40/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9973 - loss: 0.7174
# Epoch 40: val_loss improved from 1.19247 to 1.18197, saving model to best_simple_cnn.keras
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - accuracy: 0.9973 - loss: 0.7174 - val_accuracy: 0.7718 - val_loss: 1.1820 - learning_rate: 6.2500e-05
# Epoch 41/50
# 246/247 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9984 - loss: 0.7074
# Epoch 41: val_loss did not improve from 1.18197
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9984 - loss: 0.7074 - val_accuracy: 0.7539 - val_loss: 1.2164 - learning_rate: 6.2500e-05
# Epoch 42/50
# 245/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9970 - loss: 0.7068
# Epoch 42: val_loss did not improve from 1.18197
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.9970 - loss: 0.7068 - val_accuracy: 0.7694 - val_loss: 1.1858 - learning_rate: 6.2500e-05
# Epoch 43/50
# 245/247 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9974 - loss: 0.6998
# Epoch 43: val_loss did not improve from 1.18197
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9974 - loss: 0.6997 - val_accuracy: 0.7551 - val_loss: 1.1989 - learning_rate: 6.2500e-05
# Epoch 44/50
# 246/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9989 - loss: 0.6941
# Epoch 44: val_loss improved from 1.18197 to 1.17839, saving model to best_simple_cnn.keras
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - accuracy: 0.9989 - loss: 0.6941 - val_accuracy: 0.7670 - val_loss: 1.1784 - learning_rate: 3.1250e-05
# Epoch 45/50
# 246/247 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9987 - loss: 0.6870
# Epoch 45: val_loss did not improve from 1.17839
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9987 - loss: 0.6870 - val_accuracy: 0.7790 - val_loss: 1.1788 - learning_rate: 3.1250e-05
# Epoch 46/50
# 246/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9988 - loss: 0.6803
# Epoch 46: val_loss did not improve from 1.17839
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.9988 - loss: 0.6803 - val_accuracy: 0.7670 - val_loss: 1.1792 - learning_rate: 3.1250e-05
# Epoch 47/50
# 246/247 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9982 - loss: 0.6778
# Epoch 47: val_loss improved from 1.17839 to 1.17486, saving model to best_simple_cnn.keras
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - accuracy: 0.9982 - loss: 0.6778 - val_accuracy: 0.7754 - val_loss: 1.1749 - learning_rate: 3.1250e-05
# Epoch 48/50
# 246/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9990 - loss: 0.6715
# Epoch 48: val_loss improved from 1.17486 to 1.14774, saving model to best_simple_cnn.keras
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - accuracy: 0.9990 - loss: 0.6715 - val_accuracy: 0.7790 - val_loss: 1.1477 - learning_rate: 3.1250e-05
# Epoch 49/50
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9998 - loss: 0.6700
# Epoch 49: val_loss did not improve from 1.14774
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.9998 - loss: 0.6700 - val_accuracy: 0.7742 - val_loss: 1.1610 - learning_rate: 3.1250e-05
# Epoch 50/50
# 246/247 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9980 - loss: 0.6647
# Epoch 50: val_loss did not improve from 1.14774
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.9980 - loss: 0.6647 - val_accuracy: 0.7718 - val_loss: 1.1633 - learning_rate: 3.1250e-05
# Restoring model weights from the end of the best epoch: 48.

# %% [markdown]
# # Evaluation

# %%
# Make predictions on the test data
print("Making predictions...")
y_pred = model_robust.predict(X_val)
y_pred_classes = np.argmax(y_pred, axis=1) # Convert probabilities to class indices
y_true = np.argmax(y_val, axis=1)          # Convert true labels to class indices

# Plot the confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)

plt.figure(figsize=(8, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=label_encoder.classes_,
            yticklabels=label_encoder.classes_)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix: Where does the model fail?')
plt.show()

# Detailed classification report
print("\nClassification Report:\n")
print(classification_report(y_true, y_pred_classes, target_names=label_encoder.classes_))
# Out:
# Making predictions...
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step
# Classification Report:
#
#                   precision    recall  f1-score   support
#
#  air_conditioner       0.74      0.86      0.79       100
#         car_horn       0.97      0.94      0.95        33
# children_playing       0.68      0.76      0.72       100
#         dog_bark       0.76      0.78      0.77       100
#         drilling       0.78      0.83      0.81       100
#    engine_idling       0.82      0.49      0.62        93
#         gun_shot       0.97      0.97      0.97        32
#       jackhammer       0.68      0.97      0.80        96
#            siren       0.87      0.58      0.70        83
#     street_music       0.92      0.80      0.86       100
#
#         accuracy                           0.78       837
#        macro avg       0.82      0.80      0.80       837
#     weighted avg       0.79      0.78      0.77       837

# %% [markdown]
# ## Prediction Probabilities

# %%
# Calculate prediction probabilities
y_pred_probs = model_robust.predict(X_val)

# Calculate Top-1 Accuracy (standard accuracy)
top1 = tf.keras.metrics.top_k_categorical_accuracy(y_val, y_pred_probs, k=1)
print(f"Top-1 Accuracy: {np.mean(top1):.2%}")

# Calculate Top-2 Accuracy (is the correct answer within the top 2 predictions?)
top2 = tf.keras.metrics.top_k_categorical_accuracy(y_val, y_pred_probs, k=2)
print(f"Top-2 Accuracy: {np.mean(top2):.2%}")

# Calculate Top-3 Accuracy
top3 = tf.keras.metrics.top_k_categorical_accuracy(y_val, y_pred_probs, k=3)
print(f"Top-3 Accuracy: {np.mean(top3):.2%}")
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Top-1 Accuracy: 77.90%
# Top-2 Accuracy: 88.77%
# Top-3 Accuracy: 93.07%

# %% [markdown]
# ## AUC-ROC Plot

# %%
# Plot settings
plt.figure(figsize=(6, 6))
classes = label_encoder.classes_

# Plot ROC curve for each class
for i in range(len(classes)):
    # Calculate ROC for class i against the rest
    fpr, tpr, _ = roc_curve(y_val[:, i], y_pred_probs[:, i])
    roc_auc = auc(fpr, tpr)

    plt.plot(fpr, tpr, label=f'{classes[i]} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2) # Line of chance (50-50)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve per Class')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Check Errors

# %%
# Find the indices where the model made errors
y_true_cls = np.argmax(y_val, axis=1)
y_pred_cls = np.argmax(y_pred_probs, axis=1)
errors = np.where(y_pred_cls != y_true_cls)[0]

# Display the first 6 errors
plt.figure(figsize=(8, 6))
for i, err_idx in enumerate(errors[:6]):
    plt.subplot(2, 3, i+1)

    # Display the spectrogram image
    # (Since it's normalized and 3-channeled, we display only the first channel)
    plt.imshow(X_val[err_idx][:,:,0], origin='lower', aspect='auto', cmap='viridis')

    true_label = classes[y_true_cls[err_idx]]
    pred_label = classes[y_pred_cls[err_idx]]
    conf = y_pred_probs[err_idx][y_pred_cls[err_idx]]

    plt.title(f"True: {true_label}\nPred: {pred_label} ({conf:.2f})", color='red')
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
def test_with_noise(model, X_data, y_data, noise_factor):
    # Copy data to avoid modifying original
    X_noisy = X_data.copy()

    # Add noise
    noise = np.random.normal(0, 1, X_noisy.shape)
    X_noisy = X_noisy + noise_factor * noise

    # Evaluate the model on noisy data
    loss, acc = model.evaluate(X_noisy, y_data, verbose=0)
    return acc

print("Robustness Test:")
print(f"Clean Data Accuracy: {test_with_noise(model_robust, X_val, y_val, 0):.2%}")
print(f"Low Noise (0.05):    {test_with_noise(model_robust, X_val, y_val, 0.05):.2%}")
print(f"Med Noise (0.1):     {test_with_noise(model_robust, X_val, y_val, 0.1):.2%}")
print(f"High Noise (0.2):    {test_with_noise(model_robust, X_val, y_val, 0.2):.2%}")
# Out:
# Robustness Test:
# Clean Data Accuracy: 77.90%
# Low Noise (0.05):    66.79%
# Med Noise (0.1):     31.66%
# High Noise (0.2):    12.07%
